# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
sentences = [
    "I love machine learning",
    "One hot encoding is useful",
    "This is a simple example",
    "Python makes preprocessing easy",
    "Practice improves your skills"
]

# %%
sentences
# Out:
# ['I love machine learning',
#  'One hot encoding is useful',
#  'This is a simple example',
#  'Python makes preprocessing easy',
#  'Practice improves your skills']

# %%
### Define the vocabulary size
voc_size = 10000

# %%
### One Hot Representation
one_hot_repr = [one_hot(words, voc_size) for words in sentences]

# %%
one_hot_repr
# Out:
# [[3861, 8782, 2724, 738],
#  [9016, 4603, 564, 3005, 9838],
#  [8991, 3005, 9799, 7650, 4118],
#  [8749, 4744, 4038, 309],
#  [6572, 6832, 6760, 4521]]

# %%
## Word Embedding Representation

from tensorflow.keras.layers import Embedding
# from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length = 8
embedded_docs = pad_sequences(one_hot_repr,padding='pre',maxlen=sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0    0 3861 8782 2724  738]
#  [   0    0    0 9016 4603  564 3005 9838]
#  [   0    0    0 8991 3005 9799 7650 4118]
#  [   0    0    0    0 8749 4744 4038  309]
#  [   0    0    0    0 6572 6832 6760 4521]]

# %%
## feature representation
dim = 10

# %%
model = Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))
model.compile('adam','mse')

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_3 (Embedding)         │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# array([[[-0.04318229,  0.01730731,  0.01227324, -0.026682  ,
#           0.01557622,  0.03476099,  0.04879305,  0.02598295,
#           0.00987409,  0.03644535],
#         [-0.04318229,  0.01730731,  0.01227324, -0.026682  ,
#           0.01557622,  0.03476099,  0.04879305,  0.02598295,
#           0.00987409,  0.03644535],
#         [-0.04318229,  0.01730731,  0.01227324, -0.026682  ,
#           0.01557622,  0.03476099,  0.04879305,  0.02598295,
#           0.00987409,  0.03644535],
#         [-0.04318229,  0.01730731,  0.01227324, -0.026682  ,
#           0.01557622,  0.03476099,  0.04879305,  0.02598295,
#           0.00987409,  0.03644535],
#         [-0.04846656, -0.00670796,  0.00895729,  0.00320171,
#          -0.02853166,  0.03777529,  0.02303895,  0.0207515 ,
#          -0.02024739, -0.01584014],
#         [-0.02464511,  0.01397158, -0.00945719, -0.03231321,
#           0.02113244, -0.01512156,  0.04171597, -0.01321496,
#          -0.03079853,  0.01352869],
#         [-0.03381652,  0.03896074, -0.00251255,  0.01884251,
#          -0.04343654, -0.0358666 ,  0.04333708, -0.04543867,
#          -0.01323467, -0.02330768],
#         [ 0.02842395, -0.04714192, -0.03489118,  0.00360055,
#          -0.03938343, -0.04280961, -0.01944462,  0.00260346,
#          -0.04994991, -0.02633021]],
#
#        [[-0.04318229,  0.01730731,  0.01227324, -0.026682  ,
#           0.01557622,  0.03476099,  0.04879305,  0.02598295,
#           0.00987409,  0.03644535],
#         [-0.04318229,  0.01730731,  0.01227324, -0.026682  ,
#           0.01557622,  0.03476099,  0.04879305,  0.02598295,
#           0.00987409,  0.03644535],
#         [-0.04318229,  0.01730731,  0.01227324, -0.026682  ,
#           0.01557622,  0.03476099,  0.04879305,  0.02598295,
#           0.00987409,  0.03644535],
#         [ 0.04044182, -0.00328844, -0.03873168, -0.00861903,
#          -0.00625725, -0.03322829, -0.01245759,  0.01739173,
#          -0.00374864,  0.03276508],
#         [ 0.02533336,  0.00337793, -0.03416722, -0.0461151 ,
#          -0.03488718,  0.01197668,  0.03968557, -0.04419303,
#           0.00357701,  0.0012124 ],
#         [-0.00470598, -0.0025141 ,  0.00632489, -0.01322776,
#           0.03965963, -0.00159074,  0.01883459, -0.02269427,
#           0.04192733,  0.01490143],
#         [ 0.00541269,  0.01757355,  0.02841682, -0.04519359,
#          -0.01363193,  0.04998541, -0.01001394, -0.00870369,
#           0.00417513,  0.04151367],
#         [-0.04218014,  0.00120841, -0.02813301, -0.02405776,
#          -0.01977208, -0.02142899,  0.0295028 , -0.01322911,
#           0.02923938, -0.01467471]],
#
#        [[-0.04318229,  0.01730731,  0.01227324, -0.026682  ,
#           0.01557622,  0.03476099,  0.04879305,  0.02598295,
#           0.00987409,  0.03644535],
#         [-0.04318229,  0.01730731,  0.01227324, -0.026682  ,
#           0.01557622,  0.03476099,  0.04879305,  0.02598295,
#           0.00987409,  0.03644535],
#         [-0.04318229,  0.01730731,  0.01227324, -0.026682  ,
#           0.01557622,  0.03476099,  0.04879305,  0.02598295,
#           0.00987409,  0.03644535],
#         [-0.01330432,  0.00500887,  0.04526215,  0.04850303,
#          -0.04086842,  0.02280558,  0.01599425,  0.00851155,
#           0.03384788, -0.03789159],
#         [ 0.00541269,  0.01757355,  0.02841682, -0.04519359,
#          -0.01363193,  0.04998541, -0.01001394, -0.00870369,
#           0.00417513,  0.04151367],
#         [ 0.02288722, -0.00293008, -0.04558921,  0.01138284,
#          -0.04175558,  0.04764238,  0.03399887, -0.0083302 ,
#           0.0267872 ,  0.04682824],
#         [-0.02426702,  0.03598343, -0.03846157, -0.00296204,
#           0.01480771,  0.02980841, -0.03542708, -0.01250463,
#           0.00073589,  0.00734673],
#         [-0.01581607, -0.01557994, -0.03100636, -0.01882929,
#          -0.0459253 , -0.02140763, -0.01233967, -0.02987953,
#          -0.01803491, -0.04842709]],
#
#        [[-0.04318229,  0.01730731,  0.01227324, -0.026682  ,
#           0.01557622,  0.03476099,  0.04879305,  0.02598295,
#           0.00987409,  0.03644535],
#         [-0.04318229,  0.01730731,  0.01227324, -0.026682  ,
#           0.01557622,  0.03476099,  0.04879305,  0.02598295,
#           0.00987409,  0.03644535],
#         [-0.04318229,  0.01730731,  0.01227324, -0.026682  ,
#           0.01557622,  0.03476099,  0.04879305,  0.02598295,
#           0.00987409,  0.03644535],
#         [-0.04318229,  0.01730731,  0.01227324, -0.026682  ,
#           0.01557622,  0.03476099,  0.04879305,  0.02598295,
#           0.00987409,  0.03644535],
#         [-0.0064299 ,  0.03340561, -0.01154444, -0.00121486,
#           0.03597163, -0.03189652,  0.02990242, -0.03177688,
#          -0.0253125 ,  0.03121176],
#         [-0.03838392, -0.04883455,  0.03168395, -0.01510901,
#          -0.0287915 ,  0.00064025, -0.022214  , -0.04441522,
#           0.03573937, -0.04577316],
#         [ 0.04387185,  0.02514702, -0.02887383,  0.01287692,
#          -0.0226475 ,  0.01457128,  0.03189759, -0.01952609,
#          -0.02785211, -0.01433463],
#         [ 0.0033459 ,  0.00705189,  0.01076134,  0.02699839,
#          -0.0150191 , -0.02572278,  0.00914717,  0.00238544,
#          -0.02762071, -0.04624777]],
#
#        [[-0.04318229,  0.01730731,  0.01227324, -0.026682  ,
#           0.01557622,  0.03476099,  0.04879305,  0.02598295,
#           0.00987409,  0.03644535],
#         [-0.04318229,  0.01730731,  0.01227324, -0.026682  ,
#           0.01557622,  0.03476099,  0.04879305,  0.02598295,
#           0.00987409,  0.03644535],
#         [-0.04318229,  0.01730731,  0.01227324, -0.026682  ,
#           0.01557622,  0.03476099,  0.04879305,  0.02598295,
#           0.00987409,  0.03644535],
#         [-0.04318229,  0.01730731,  0.01227324, -0.026682  ,
#           0.01557622,  0.03476099,  0.04879305,  0.02598295,
#           0.00987409,  0.03644535],
#         [ 0.01717868, -0.01604568, -0.02669602,  0.01600398,
#           0.01039685, -0.00084982, -0.01629741, -0.04890284,
#           0.00763991,  0.02049543],
#         [ 0.03203696,  0.02947661,  0.02470299, -0.00808195,
#           0.00676769, -0.01532303,  0.0230161 , -0.0071872 ,
#          -0.01980281,  0.03456838],
#         [ 0.04641707,  0.02137121, -0.0329759 , -0.00425901,
#          -0.00231627, -0.02023166,  0.01922084,  0.0307269 ,
#           0.00782315,  0.02372607],
#         [ 0.0046987 , -0.01266483,  0.01312331, -0.03774127,
#          -0.00694319, -0.0346455 , -0.02369634, -0.03231926,
#          -0.01157224, -0.02146267]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 3861, 8782, 2724,  738], dtype=int32)

# %%
model.predict(embedded_docs[0:1])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# array([[[-0.04318229,  0.01730731,  0.01227324, -0.026682  ,
#           0.01557622,  0.03476099,  0.04879305,  0.02598295,
#           0.00987409,  0.03644535],
#         [-0.04318229,  0.01730731,  0.01227324, -0.026682  ,
#           0.01557622,  0.03476099,  0.04879305,  0.02598295,
#           0.00987409,  0.03644535],
#         [-0.04318229,  0.01730731,  0.01227324, -0.026682  ,
#           0.01557622,  0.03476099,  0.04879305,  0.02598295,
#           0.00987409,  0.03644535],
#         [-0.04318229,  0.01730731,  0.01227324, -0.026682  ,
#           0.01557622,  0.03476099,  0.04879305,  0.02598295,
#           0.00987409,  0.03644535],
#         [-0.04846656, -0.00670796,  0.00895729,  0.00320171,
#          -0.02853166,  0.03777529,  0.02303895,  0.0207515 ,
#          -0.02024739, -0.01584014],
#         [-0.02464511,  0.01397158, -0.00945719, -0.03231321,
#           0.02113244, -0.01512156,  0.04171597, -0.01321496,
#          -0.03079853,  0.01352869],
#         [-0.03381652,  0.03896074, -0.00251255,  0.01884251,
#          -0.04343654, -0.0358666 ,  0.04333708, -0.04543867,
#          -0.01323467, -0.02330768],
#         [ 0.02842395, -0.04714192, -0.03489118,  0.00360055,
#          -0.03938343, -0.04280961, -0.01944462,  0.00260346,
#          -0.04994991, -0.02633021]]], dtype=float32)
